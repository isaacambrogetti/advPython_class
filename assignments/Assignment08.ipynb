# %% [markdown]
# <h2><center>Assignment 7</center></h2>
# <h3><center>Programming for Data Science 2026</center></h3>
# <b><center>Deadline: 14:00, April 30, 2026 </center></b>

# %% [markdown]
# - The exercise will be marked as **passed** if you get **at least 10/16** points.
#
# - For general questions about the lecture content, assignments, or the exam, please use the **ILIAS forum**.
#
# - For individual questions about lecture content and the exam, contact: *roland.widmer@students.unibe.ch*
#
# - For individual questions about the exercises or grading, contact: *julien.brunner@students.unibe.ch* or *aline.steiner@students.unibe.ch*

# %% [markdown]
# #### Task 1: Virtual environment *(2 points)*
#
# Set up a virtual environment for your project. Use **Poetry** (recommended) or another environment manager (e.g., venv, conda). Update the `.gitignore` file so that environment files are not tracked.

# %% [markdown]
# #### Task 2: First deliverable *(12 points)*
#
# Implement the first deliverable of your project according to the specifications of your project in `Projects.pdf`.
#
# - Implement all required functionality
# - Ensure the code is usable and understandable by others
# - Use branches and merge changes using pull requests (no direct commits to `main`)
# - Follow good coding practices and the general guidelines in `Projects.pdf`
#
# Grading:
#
# - 6 points: All required functionality is implemented correctly
# - 2 points: Creativity and originality (e.g., innovative features, thoughtful design choices)
# - 2 points: Code is readable and well documented
# - 1 point: Usage is intuitive (clear interface, easy to run)
# - 1 point: At least 1 pull request (GitHub)

# %% [markdown]
# #### Task 3: Update README *(2 points)*
#
# Update the `README.md` file so that others can easily run your project.
#
# Provide step-by-step instructions to:
#   - Clone the repository
#   - Install dependencies
#   - Run the project
#
# Ensure that all necessary data is available.
